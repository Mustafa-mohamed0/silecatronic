# %%
<!DOCTYPE html>
<html>
<head>
  <title>Smart Home Control</title>
  <style>
    body {
      font-family: Arial, sans-serif;
    }

    .container {
      width: 100%;
      height: 100vh;
      display: flex;
      justify-content: center;
      align-items: center;
    }

    .controls {
      display: flex;
      flex-direction: column;
      gap: 1rem;
    }

    .button {
      padding: 1rem;
      border: 1px solid #ccc;
      border-radius: 5px;
      cursor: pointer;
    }

    .button:hover {
      background-color: #ccc;
    }

    .battery-indicator {
      width: 10rem;
      height: 1rem;
      background-color: #ccc;
      border-radius: 5px;
    }

    .battery-indicator-fill {
      width: 0%;
      height: 100%;
      background-color: #00ff00;
      border-radius: 5px;
    }

    .battery-level-text {
      font-size: 1.5rem;
    }
  </style>
</head>
<body>
  <div class="container">
    <div class="controls">
      <button id="toggle-lights">Toggle Lights</button>
      <button id="toggle-power">Toggle Power</button>
      <button id="toggle-ac">Toggle AC</button>
      <button id="toggle-fan">Toggle Fan</button>
      <button id="toggle-sprinkler">Toggle Sprinkler</button>
    </div>
    <div class="battery-indicator">
      <div class="battery-indicator-fill"></div>
    </div>
    <span class="battery-level-text">0%</span>
  </div>

  <script>
    const toggleLightsButton = document.getElementById('toggle-lights');
    const togglePowerButton = document.getElementById('toggle-power');
    const toggleAcButton = document.getElementById('toggle-ac');
    const toggleFanButton = document.getElementById('toggle-fan');
    const toggleSprinklerButton = document.getElementById('toggle-sprinkler');
    const batteryIndicatorFill = document.querySelector('.battery-indicator-fill');
    const batteryLevelText = document.querySelector('.battery-level-text');

    toggleLightsButton.addEventListener('click', () => {
      // Send a request to the home controller to toggle the lights
    });

    togglePowerButton.addEventListener('click', () => {
      // Send a request to the home controller to toggle the power
    });

    toggleAcButton.addEventListener('click', () => {
      // Send a request to the home controller to toggle the AC
    });

    toggleFanButton.addEventListener('click', () => {
      // Send a request to the home controller to toggle the fan
    });

    toggleSprinklerButton.addEventListener('click', () => {
      // Send a request to the home controller to toggle the sprinkler
    });

    // Add an event listener to update the battery level every second
    setInterval(updateBatteryLevel, 1000);

    function updateBatteryLevel() {
      // Get the battery level as a percentage
      const batteryLevel = getBatteryLevel();

      // Update the battery indicator fill and text
      batteryIndicatorFill.style.width = `${batteryLevel}%`;
      batteryLevelText.textContent = `${batteryLevel}%`;
    }

    // Function to get the battery level
    function getBatteryLevel() {
      // Replace this with the actual code to get the battery level
      return Math.random() * 100;
    }
  </script>
</body>
</html>
import socket

# Create a network socket
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# Bind the socket to a port
s.bind(('127.0.0.1', 5000))

# Listen for incoming connections
s.listen(5)

while True:
    # Accept an incoming connection
    conn, addr = s.accept()

    # Receive data from the client
    data = conn.recv(10)
# Out:
#   Cell In[5], line 12
#     height: 100vh;
#               ^
# SyntaxError: invalid decimal literal
